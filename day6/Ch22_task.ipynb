# %% [markdown]
# 여러 숫자를 입력받아 그 합계를 반환하는 함수 sum_numbers를 작성하세요. 이 때, 가변 매개변수를 사용하세요.

# %%
def sum_numbers(a, b, c):
    reult = a + b + c
    return reult
reult = sum_numbers("나는" , "겁나똑똑해" , "잘할수있어!")

print(reult)
# Out:
# 나는겁나똑똑해잘할수있어!

# %% [markdown]
# 함수를 정해주는 def 가저와 sum_numbers() 함수로 지정하고
#
# ()안에 매개변수 a b c 를 넣는다
#
# def sum_numbers(a, b, c):
#
# reult 결과에 = a + b + c 매개변수 의 갑을 더한다는걸 대입하고
#
# reult = a + b + c
#
# 다시 리턴하여 sum_numbers에 입력
#
# return reult
#
# sum_numbers 함수에 a , b , c 의 들어갈 문자를 넣는다
#
# reult = sum_numbers("나는" ,
# "겁나똑똑해" , "잘할수있어!")
#
# reult 결과를 받는다
#
# print(reult)
