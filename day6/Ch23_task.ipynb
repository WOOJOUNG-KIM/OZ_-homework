# %% [markdown]
# 사용자의 이름을 출력하는 함수 print_name을 작성하세요. 만약 이름이 주어지지 않았다면, 기본값으로 "익명"을 사용하세요.

# %%
def print_name(name="익명"):

    print(name)


print_name()
# Out:
# 익명

# %% [markdown]
# 함수를 정해주는 def를 사요해서 print_name() 함수로 정해주고
#
# 질문을 보고 맞는지는 모르지만일단 기본 값을 익명으로 하라고하여
#
# print_name () 안에 name = 익명 으로 정했습니다
#
# 그런후 그냥 프린트 하면 되겠지 마음에 print(name)를 했지만 이것또한 정해준 함수
#
# print_name() 을 입력해야 나왔습니다
#
# 피트백 있음 부탁드립니다
