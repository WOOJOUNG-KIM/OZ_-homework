# %% [markdown]
# 두 숫자를 더하는 람다 함수를 작성하고, 이를 변수에 할당한 후 사용하세요.

# %%
def a(s, d):
    return s + d

result = a(10 , 20)
print(result)
# Out:
# 30

# %% [markdown]
# def를 이용해 a 를 함수라 칭하고 a() 안에 s,d 의 매개변수를 넣고
#
# def a(s, d):
#
# return 리턴을 사용하여 s + d 의 수를 더하고 a()에 돌려 받는다
#
#    return s + d
#
# result 결과에 a() 안에 10 과 20을 넣어 s는 10 d는 20 이라는 걸 적용하여
#
# result = a(10 , 20)
#
# 결과를 출력을 했습니다
#
# print(result)
